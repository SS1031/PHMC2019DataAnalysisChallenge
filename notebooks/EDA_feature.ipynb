# %%
import os
import sys
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
sys.path.append('../src/')
import CONST

from _110_feature import _110_feature

trn_path, tst_path = _110_feature()

# %%
trn = pd.read_feather(trn_path)
tst = pd.read_feather(tst_path)

# %%
trn.columns
# Out:
# Index(['Engine', 'FlightRegime__length', 'FlightRegime__maximum',
#        'FlightRegime__mean', 'FlightRegime__median', 'FlightRegime__minimum',
#        'FlightRegime__standard_deviation', 'FlightRegime__sum_values',
#        'FlightRegime__variance', 'OffsetBprBypassRatio__length',
#        'OffsetBprBypassRatio__maximum', 'OffsetBprBypassRatio__mean',
#        'OffsetBprBypassRatio__median', 'OffsetBprBypassRatio__minimum',
#        'OffsetBprBypassRatio__standard_deviation',
#        'OffsetBprBypassRatio__sum_values', 'OffsetBprBypassRatio__variance',
#        'OffsetHtbleedBleedEnthalpy__length',
#        'OffsetHtbleedBleedEnthalpy__maximum',
#        'OffsetHtbleedBleedEnthalpy__mean',
#        'OffsetHtbleedBleedEnthalpy__median',
#        'OffsetHtbleedBleedEnthalpy__minimum',
#        'OffsetHtbleedBleedEnthalpy__standard_deviation',
#        'OffsetHtbleedBleedEnthalpy__sum_values',
#        'OffsetHtbleedBleedEnthalpy__variance',
# ...

# %%
plt.plot(trn.OffsetPs30StaticPressureAtHpcOutletPsia__sum_values, trn.RUL, 'o')

# %%
plt.plot(trn.OffsetPs30StaticPressureAtHpcOutletPsia__maximum, trn.RUL, 'o')

# %%
plt.plot(trn.OffsetBprBypassRatio__standard_deviation, trn.RUL, 'o')
